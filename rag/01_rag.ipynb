# %%
import os
from openai import OpenAI

from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.environ.get("ANTHROPIC_API_KEY"),
    base_url="https://api.anthropic.com/v1/",
)

# %%
from libs.ingest import load_all_faqs, build_index
from libs.rag import RAGBase

documents = load_all_faqs()
index = build_index(documents)
assistant = RAGBase(
    index=index,
    llm_client=client,
)

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# # Yes, you can join now!
#
# According to the course information, **yes, you can join the course at any time**. Here are the key points:
#
# 1. **You can start whenever you want** - The videos and GitHub materials are available, and you can begin learning immediately.
#
# 2. **Certificate requirement** - If you want to receive a certificate, you'll need to:
#    - Submit your project while submissions are still being accepted
#    - Complete the course with a "live" cohort (not in self-paced mode)
#    - Complete the peer-review process for 3 capstone projects
#
# 3. **Getting started** - To begin, you should:
#    - Check the [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/)
#    - Review the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/) for deadlines
#    - Start with the lesson videos and work through the materials
#
# So while you can join anytime, make sure to check the **submission deadlines** if you want to be eligible for a certificate!
